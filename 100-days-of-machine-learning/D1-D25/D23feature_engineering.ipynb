# %% [markdown]
# <a href="https://colab.research.google.com/github/rani-sneha/DataScience/blob/main/100-days-of-machine-learning/D1-D25/D23feature_engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Even if you  give good features to a bad model it will give better results than giving worst features to best model.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Feature Engineering
# 1. Feature transformation:-
#    a. Missing Value Imputation
#    b. Handling Categorical Features
#    c. Outlier Detection
#    d. Feature Scaling
# 2. Feature Construction:- All the features are not already present in data. You manually add features which you cnsider important.
# 3. Feature Selection:-All the columns are not important. YOu select some columns which have an impact on the result.
# 4. Feature Extraction:- Programitcally you try to extract some features not manually.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Either remove those missing values or fill those missing vlaues.
# There are several ways to fill like filling with mean median mode.If the data is categorical then we fill with values which is used maximum.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Handling Categorical Value
# One part encodindg.

# %% [markdown]
# Outlier Detection:-
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Feature Scaling:-
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is Feature Engineering?**
#
# Feature Scaling is a technique to standarfize the independent features present in the dat in fixed range.
#
# **Why do we need feature scaling?**
#
# In certain machine learning models, it calcultes distance and if values of two columns vary a lot and one of the values will overpower the other.

# %% [markdown]
# **What are the types of feature engeering available?**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Standardization
#
# How to standardize?
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Before and after scaling**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Outliers should be removed.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Where standardize not required?
# 1. Decision Trees
# 2. Random Forest

# %% [markdown]
# #Normalization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. Min-Max Scaling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The shape of distribution can change.
# Since we are sqishing from 0 to 1.  Therefore the impact of outlier also changes

# %% [markdown]
# **2. Mean Modelization**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Max Abs Scaling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  **3. Robust Scaling**
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Normalization vs Standardization
