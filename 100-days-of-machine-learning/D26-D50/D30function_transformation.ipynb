# %% [markdown]
# <a href="https://colab.research.google.com/github/rani-sneha/DataScience/blob/main/100-days-of-machine-learning/D26-D50/D30function_transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mathematical Transformations
# You apply a mathematical formula to columns convert the columns into desired form.
# We do this to convert its pdf to normal distribution
#  It is very easy to solve problems when facing normal distributions.
#
#  Some ml algo work better with normal distributions. So end goal--> normal distribution using algo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #log Transform
# :You just take log of the values to convert it into normal distribution
# When can it not be used.
# 1. Cannot be used in negative values.
#
# Can be used in right skewed data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
