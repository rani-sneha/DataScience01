# %% [markdown]
# <a href="https://colab.research.google.com/github/rani-sneha/DataScience/blob/main/100-days-of-machine-learning/D26-D50/D27one_hot_encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We cannot do this because this is ordinal coding and in ordinal coding we say that Red has higher value than yellow or blue then we use one hot encoding.
# like:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Dummy Variable Trap

# %% [markdown]
# When you have n columns then we remove one column and use n-1 colums.
# There is concept of multicoliniarity.
# You consider that i/p columns should not depend on each other.
# Dummy columns get created and a trap of dummy columns happens. So you remove 1st column.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You only keep frequent categories and the categories which are not frequent then you keep them in other.

# %% [markdown]
# #One Hot Coding

# %% [markdown]
# ```
# # This is formatted as code
# import numpy as np
# import pandas as pd
# df['brand'].nunique()
# #Tells the total unique brands available.
# df['fuel'].value_counts()
#
# #One hot encoding using pandas
#
# pd.get_dummies(df, columns={'fuel', 'owner'})
# ```
#
# https://github.com/campusx-official/100-days-of-machine-learning/blob/main/day27-one-hot-encoding/day27.ipynb
#
# https://github.com/campusx-official/100-days-of-machine-learning/blob/main/day27-one-hot-encoding/cars.csv

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Removes first columns. We don't use pandas because it does remember the position of columns so we use skleran.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
